# %% [markdown]
# <a href="https://colab.research.google.com/github/UNIBOY04/JQuery-UI-Prototype-like-Whatsapp-Clone/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel(r"/content/datsets 1.xlsx")

# %%
df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temp         7738 non-null   int64
#  1   Strain_rate  7738 non-null   float64
#  2   Strain       7738 non-null   float64
#  3   Stress       7738 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 241.9 KB

# %%
import matplotlib.pyplot as plt
x = df[ "Strain"]
y = df ["Stress"]
plt.plot(x,y)

# %%
import seaborn as sns
sns.pairplot(data = df)
df.corr()
# Out:
#                  Temp  Strain_rate    Strain    Stress
# Temp         1.000000     0.015025 -0.009502 -0.828828
# Strain_rate  0.015025     1.000000 -0.049881  0.139984
# Strain      -0.009502    -0.049881  1.000000  0.261432
# Stress      -0.828828     0.139984  0.261432  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# Fibonacci Series

n = int(input("Enter the number of terms: "))

a = 0
b = 1

print("Fibonacci Series:")

for i in range(n):
    print(a, end=" ")
    c = a + b
    a = b
    b = c
# Out:
# Enter the number of terms: 7
# Fibonacci Series:
# 0 1 1 2 3 5 8
